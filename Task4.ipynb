# %% [markdown]
# <a href="https://colab.research.google.com/github/OIegsandr/DEiAPUrazbaev/blob/main/Task4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sympy as sp

# %%
m = sp.symbols('m')
k = sp.symbols("k")
t = sp.symbols("t")
x = sp.symbols("x")

# %%
k = (sp.ln(2) / 1590)
x = k.evalf()

# %%
m = sp.exp(-x * t)
m_200 = m.subs(t, 200)

persentage = (1 - m_200) * 100
print(persentage, "%")
# Out:
# 8.34955209585673 %
