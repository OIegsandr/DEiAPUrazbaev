# %% [markdown]
# <a href="https://colab.research.google.com/github/OIegsandr/DEiAPUrazbaev/blob/main/ThirdTask.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sympy as sp

# %%
x = sp.symbols("x")
y = sp.symbols("y")
C = sp.symbols("C")

# %%
sp.diff(x**3 + 4*(x**2) - 1, x) #1
# Out:
# 3*x**2 + 8*x

# %%
sp.diff(sp.ln(x), x) #2
# Out:
# 1/x

# %%
sp.diff(sp.exp(x), x) #3
# Out:
# exp(x)

# %%
f = 2*sp.cos(x) - sp.exp(x/2)
sp.diff(f, x) #4
# Out:
# -exp(x/2)/2 - 2*sin(x)

# %%
sp.integrate(sp.tan(x), x)
# Out:
# -log(cos(x))

# %%
sp.integrate(sp.ln(x), x)
# Out:
# x*log(x) - x

# %%
sp.plot(x**2)

# %%
sp.plot(x**2, (x, -2, 2), ylim=(-3, 3))

# %%
sp.plot([x, x**2, x**3, x**-1], (x, -2, 2), ylim=(-4, 4))

# %%
sp.plot_implicit((x**2 + y**2 - 1), (x, -1, 1), (y, -1, 1))

# %%
sp.plot(*[x**2 + C for C in range(-4, 5)], (x, -2, 2), ylim=(-4, 4))
